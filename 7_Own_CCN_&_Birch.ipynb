# %% [markdown]
# <a href="https://colab.research.google.com/github/Volks44/Proj_Lab1/blob/main/7_Own_CCN_%26_Birch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.datasets import cifar10
# !pip install np_utils --quiet
import np_utils as np_utils
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers, optimizers
import numpy as np
from matplotlib import pyplot
from keras.models import Sequential
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 1.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for np_utils (setup.py) ... done

# %%
# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 2s 0us/step

# %%
# Classes division
classes_for_clas = [0, 1, 2, 3, 4, 5]
classes_for_clus = [6,7,8,9]

# Filtering the data for classification
train_mask = np.isin(train_labels, classes_for_clas).flatten()
test_mask = np.isin(test_labels, classes_for_clas).flatten()

x_train_clas = train_images[train_mask]
y_train_clas = train_labels[train_mask]

x_test_clas = test_images[test_mask]
y_test_clas = test_labels[test_mask]

# Filtering the data for clustering
train_mask = np.isin(train_labels, classes_for_clus).flatten()
test_mask = np.isin(test_labels, classes_for_clus).flatten()

x_train_clus = train_images[train_mask]
y_train_clus = train_labels[train_mask]

x_test_clus = test_images[test_mask]
y_test_clus = test_labels[test_mask]

# %%
# rescale [0,255] --> [0,1]
x_train_clas = x_train_clas.astype('float32')/255
x_test_clas = x_test_clas.astype('float32')/255

# %%
x_train_clas.shape
# Out:
# (30000, 32, 32, 3)

# %%
# one-hot encode the labels
num_classes = len(np.unique(y_train_clas))
y_train_clas = keras.utils.to_categorical(y_train_clas, num_classes)
y_test_clas = keras.utils.to_categorical(y_test_clas, num_classes)

# break training set into training and validation sets
(x_train_clas, x_valid_clas) = x_train_clas[5000:], x_train_clas[:5000]
(y_train_clas, y_valid_clas) = y_train_clas[5000:], y_train_clas[:5000]

# print shape of training set
print('x_train shape:', x_train_clas.shape)

# print number of training, validation, and test images
print(x_train_clas.shape[0], 'train samples')
print(x_test_clas.shape[0], 'test samples')
print(x_valid_clas.shape[0], 'validation samples')
# Out:
# x_train shape: (25000, 32, 32, 3)
# 25000 train samples
# 6000 test samples
# 5000 validation samples

# %%
# number of hidden units variable
base_hidden_units = 32

# l2 regularization hyperparameter
weight_decay = 1e-4

model = Sequential()

# CONV1
# notice that we defined the input_shape here because this is the first CONV layer.
# we don’t need to do that for the remaining layers
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train_clas.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV2
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# CONV3
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV4
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

# CONV5
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV6
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

# FC7
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

# print model summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  batch_normalization (Batch  (None, 32, 32, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_2 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_3 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_4 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_5 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 6)                 12294
#
# =================================================================
# Total params: 301094 (1.15 MB)
# Trainable params: 300198 (1.15 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
    )

# compute the data augmentation on the training set
datagen.fit(x_train_clas)

# %%
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

# training
batch_size = 64
epochs=100

checkpointer = ModelCheckpoint(filepath='model.100epochs.hdf5', verbose=1, save_best_only=True)

optimizer = Adam(learning_rate=0.0001)

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
history = model.fit(datagen.flow(x_train_clas, y_train_clas, batch_size=batch_size), callbacks=[checkpointer],
                steps_per_epoch=x_train_clas.shape[0] // batch_size, epochs=epochs,verbose=2,
                validation_data=(x_test_clas,y_test_clas))
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 1.95768, saving model to model.100epochs.hdf5
# 390/390 - 42s - loss: 2.3897 - accuracy: 0.3333 - val_loss: 1.9577 - val_accuracy: 0.2533 - 42s/epoch - 107ms/step
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 1.95768 to 1.34550, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 1.7801 - accuracy: 0.4088 - val_loss: 1.3455 - val_accuracy: 0.4957 - 17s/epoch - 45ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 1.34550
# 390/390 - 16s - loss: 1.5617 - accuracy: 0.4526 - val_loss: 1.4521 - val_accuracy: 0.4722 - 16s/epoch - 41ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.34550 to 1.26870, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.4601 - accuracy: 0.4762 - val_loss: 1.2687 - val_accuracy: 0.5208 - 16s/epoch - 40ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.26870 to 1.26701, saving model to model.100epochs.hdf5
# 390/390 - 19s - loss: 1.4051 - accuracy: 0.4945 - val_loss: 1.2670 - val_accuracy: 0.5398 - 19s/epoch - 49ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.26701 to 1.21419, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.3589 - accuracy: 0.5110 - val_loss: 1.2142 - val_accuracy: 0.5332 - 16s/epoch - 40ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.21419 to 1.19693, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.3005 - accuracy: 0.5267 - val_loss: 1.1969 - val_accuracy: 0.5335 - 16s/epoch - 40ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 1.19693
# 390/390 - 17s - loss: 1.2797 - accuracy: 0.5367 - val_loss: 1.2574 - val_accuracy: 0.5210 - 17s/epoch - 43ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 1.19693
# 390/390 - 16s - loss: 1.2429 - accuracy: 0.5509 - val_loss: 1.2026 - val_accuracy: 0.5418 - 16s/epoch - 41ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 1.19693
# 390/390 - 16s - loss: 1.2093 - accuracy: 0.5578 - val_loss: 1.2124 - val_accuracy: 0.5527 - 16s/epoch - 42ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 1.19693
# 390/390 - 16s - loss: 1.1810 - accuracy: 0.5746 - val_loss: 1.2133 - val_accuracy: 0.5437 - 16s/epoch - 42ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 1.19693
# 390/390 - 17s - loss: 1.1487 - accuracy: 0.5802 - val_loss: 1.2381 - val_accuracy: 0.5420 - 17s/epoch - 44ms/step
# Epoch 13/100
#
# Epoch 13: val_loss did not improve from 1.19693
# 390/390 - 16s - loss: 1.1186 - accuracy: 0.5939 - val_loss: 1.2837 - val_accuracy: 0.5275 - 16s/epoch - 40ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 1.19693
# 390/390 - 16s - loss: 1.0909 - accuracy: 0.6011 - val_loss: 1.2644 - val_accuracy: 0.5457 - 16s/epoch - 42ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 1.19693 to 1.18498, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.0680 - accuracy: 0.6037 - val_loss: 1.1850 - val_accuracy: 0.5640 - 16s/epoch - 42ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 1.18498 to 1.12838, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.0436 - accuracy: 0.6175 - val_loss: 1.1284 - val_accuracy: 0.5847 - 16s/epoch - 42ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 1.12838 to 1.07420, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.0188 - accuracy: 0.6284 - val_loss: 1.0742 - val_accuracy: 0.6172 - 16s/epoch - 42ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 1.07420
# 390/390 - 16s - loss: 0.9985 - accuracy: 0.6331 - val_loss: 1.1582 - val_accuracy: 0.5727 - 16s/epoch - 42ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 1.07420 to 1.06925, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.9863 - accuracy: 0.6406 - val_loss: 1.0692 - val_accuracy: 0.6092 - 17s/epoch - 43ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 1.06925 to 1.03791, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.9686 - accuracy: 0.6434 - val_loss: 1.0379 - val_accuracy: 0.6208 - 16s/epoch - 41ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 1.03791
# 390/390 - 16s - loss: 0.9465 - accuracy: 0.6503 - val_loss: 1.1181 - val_accuracy: 0.6155 - 16s/epoch - 42ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 1.03791 to 0.98225, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.9347 - accuracy: 0.6558 - val_loss: 0.9823 - val_accuracy: 0.6507 - 16s/epoch - 42ms/step
# Epoch 23/100
#
# Epoch 23: val_loss did not improve from 0.98225
# 390/390 - 17s - loss: 0.9246 - accuracy: 0.6590 - val_loss: 1.0792 - val_accuracy: 0.6302 - 17s/epoch - 44ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.98225
# 390/390 - 16s - loss: 0.9059 - accuracy: 0.6654 - val_loss: 1.0220 - val_accuracy: 0.6348 - 16s/epoch - 42ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.98225 to 0.92089, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.8967 - accuracy: 0.6692 - val_loss: 0.9209 - val_accuracy: 0.6698 - 16s/epoch - 41ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.92089
# 390/390 - 17s - loss: 0.8798 - accuracy: 0.6742 - val_loss: 1.0162 - val_accuracy: 0.6545 - 17s/epoch - 45ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.92089
# 390/390 - 16s - loss: 0.8664 - accuracy: 0.6811 - val_loss: 0.9315 - val_accuracy: 0.6772 - 16s/epoch - 42ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.92089
# 390/390 - 16s - loss: 0.8593 - accuracy: 0.6819 - val_loss: 0.9374 - val_accuracy: 0.6737 - 16s/epoch - 40ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.92089 to 0.86746, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.8467 - accuracy: 0.6876 - val_loss: 0.8675 - val_accuracy: 0.6868 - 16s/epoch - 40ms/step
# Epoch 30/100
#
# Epoch 30: val_loss did not improve from 0.86746
# 390/390 - 16s - loss: 0.8321 - accuracy: 0.6966 - val_loss: 0.9923 - val_accuracy: 0.6673 - 16s/epoch - 40ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.86746
# 390/390 - 16s - loss: 0.8208 - accuracy: 0.6979 - val_loss: 0.9201 - val_accuracy: 0.6805 - 16s/epoch - 42ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.86746
# 390/390 - 16s - loss: 0.8098 - accuracy: 0.6995 - val_loss: 0.8910 - val_accuracy: 0.6835 - 16s/epoch - 41ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.86746 to 0.85797, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.8034 - accuracy: 0.7062 - val_loss: 0.8580 - val_accuracy: 0.7003 - 16s/epoch - 41ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.85797 to 0.80894, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.8014 - accuracy: 0.7094 - val_loss: 0.8089 - val_accuracy: 0.7085 - 17s/epoch - 42ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.80894
# 390/390 - 16s - loss: 0.7924 - accuracy: 0.7114 - val_loss: 0.8318 - val_accuracy: 0.7005 - 16s/epoch - 41ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.80894
# 390/390 - 16s - loss: 0.7815 - accuracy: 0.7150 - val_loss: 0.8237 - val_accuracy: 0.7127 - 16s/epoch - 40ms/step
# Epoch 37/100
#
# Epoch 37: val_loss improved from 0.80894 to 0.80309, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.7704 - accuracy: 0.7186 - val_loss: 0.8031 - val_accuracy: 0.7198 - 16s/epoch - 41ms/step
# Epoch 38/100
#
# Epoch 38: val_loss improved from 0.80309 to 0.75381, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.7718 - accuracy: 0.7168 - val_loss: 0.7538 - val_accuracy: 0.7345 - 17s/epoch - 44ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.75381
# 390/390 - 16s - loss: 0.7647 - accuracy: 0.7231 - val_loss: 0.8172 - val_accuracy: 0.7127 - 16s/epoch - 40ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.75381
# 390/390 - 16s - loss: 0.7517 - accuracy: 0.7270 - val_loss: 0.7827 - val_accuracy: 0.7200 - 16s/epoch - 42ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.75381
# 390/390 - 17s - loss: 0.7486 - accuracy: 0.7291 - val_loss: 0.8289 - val_accuracy: 0.7097 - 17s/epoch - 43ms/step
# Epoch 42/100
#
# Epoch 42: val_loss improved from 0.75381 to 0.74390, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.7405 - accuracy: 0.7301 - val_loss: 0.7439 - val_accuracy: 0.7348 - 16s/epoch - 41ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.74390
# 390/390 - 17s - loss: 0.7337 - accuracy: 0.7360 - val_loss: 0.8008 - val_accuracy: 0.7215 - 17s/epoch - 42ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.74390
# 390/390 - 16s - loss: 0.7287 - accuracy: 0.7332 - val_loss: 0.8098 - val_accuracy: 0.7123 - 16s/epoch - 41ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.74390
# 390/390 - 17s - loss: 0.7295 - accuracy: 0.7356 - val_loss: 0.7555 - val_accuracy: 0.7385 - 17s/epoch - 43ms/step
# Epoch 46/100
#
# Epoch 46: val_loss improved from 0.74390 to 0.72397, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.7257 - accuracy: 0.7384 - val_loss: 0.7240 - val_accuracy: 0.7465 - 17s/epoch - 42ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.72397
# 390/390 - 16s - loss: 0.7209 - accuracy: 0.7396 - val_loss: 0.7977 - val_accuracy: 0.7227 - 16s/epoch - 41ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.72397
# 390/390 - 17s - loss: 0.7139 - accuracy: 0.7437 - val_loss: 0.7576 - val_accuracy: 0.7348 - 17s/epoch - 43ms/step
# Epoch 49/100
#
# Epoch 49: val_loss improved from 0.72397 to 0.71977, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.7111 - accuracy: 0.7429 - val_loss: 0.7198 - val_accuracy: 0.7432 - 16s/epoch - 42ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.71977
# 390/390 - 17s - loss: 0.7047 - accuracy: 0.7475 - val_loss: 0.7840 - val_accuracy: 0.7268 - 17s/epoch - 42ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.71977
# 390/390 - 17s - loss: 0.6920 - accuracy: 0.7518 - val_loss: 0.7395 - val_accuracy: 0.7408 - 17s/epoch - 43ms/step
# Epoch 52/100
#
# Epoch 52: val_loss improved from 0.71977 to 0.71668, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6892 - accuracy: 0.7513 - val_loss: 0.7167 - val_accuracy: 0.7455 - 16s/epoch - 41ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.71668
# 390/390 - 17s - loss: 0.6869 - accuracy: 0.7510 - val_loss: 0.7357 - val_accuracy: 0.7363 - 17s/epoch - 44ms/step
# Epoch 54/100
#
# Epoch 54: val_loss improved from 0.71668 to 0.70062, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.6862 - accuracy: 0.7506 - val_loss: 0.7006 - val_accuracy: 0.7485 - 17s/epoch - 43ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.70062
# 390/390 - 16s - loss: 0.6808 - accuracy: 0.7565 - val_loss: 0.7015 - val_accuracy: 0.7558 - 16s/epoch - 41ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.70062
# 390/390 - 16s - loss: 0.6803 - accuracy: 0.7572 - val_loss: 0.7454 - val_accuracy: 0.7433 - 16s/epoch - 41ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.70062
# 390/390 - 16s - loss: 0.6689 - accuracy: 0.7593 - val_loss: 0.7210 - val_accuracy: 0.7572 - 16s/epoch - 41ms/step
# Epoch 58/100
#
# Epoch 58: val_loss improved from 0.70062 to 0.69933, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6683 - accuracy: 0.7613 - val_loss: 0.6993 - val_accuracy: 0.7530 - 16s/epoch - 42ms/step
# Epoch 59/100
#
# Epoch 59: val_loss improved from 0.69933 to 0.69828, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6600 - accuracy: 0.7630 - val_loss: 0.6983 - val_accuracy: 0.7512 - 16s/epoch - 42ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.69828
# 390/390 - 18s - loss: 0.6585 - accuracy: 0.7669 - val_loss: 0.7068 - val_accuracy: 0.7527 - 18s/epoch - 46ms/step
# Epoch 61/100
#
# Epoch 61: val_loss improved from 0.69828 to 0.69733, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6652 - accuracy: 0.7644 - val_loss: 0.6973 - val_accuracy: 0.7567 - 16s/epoch - 42ms/step
# Epoch 62/100
#
# Epoch 62: val_loss improved from 0.69733 to 0.67643, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.6577 - accuracy: 0.7647 - val_loss: 0.6764 - val_accuracy: 0.7617 - 17s/epoch - 44ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.67643
# 390/390 - 16s - loss: 0.6456 - accuracy: 0.7722 - val_loss: 0.6806 - val_accuracy: 0.7620 - 16s/epoch - 42ms/step
# Epoch 64/100
#
# Epoch 64: val_loss improved from 0.67643 to 0.67576, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6474 - accuracy: 0.7673 - val_loss: 0.6758 - val_accuracy: 0.7605 - 16s/epoch - 41ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.67576
# 390/390 - 17s - loss: 0.6504 - accuracy: 0.7697 - val_loss: 0.6880 - val_accuracy: 0.7625 - 17s/epoch - 43ms/step
# Epoch 66/100
#
# Epoch 66: val_loss improved from 0.67576 to 0.67079, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6350 - accuracy: 0.7715 - val_loss: 0.6708 - val_accuracy: 0.7670 - 16s/epoch - 41ms/step
# Epoch 67/100
#
# Epoch 67: val_loss improved from 0.67079 to 0.66594, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.6334 - accuracy: 0.7718 - val_loss: 0.6659 - val_accuracy: 0.7692 - 17s/epoch - 43ms/step
# Epoch 68/100
#
# Epoch 68: val_loss improved from 0.66594 to 0.62887, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6349 - accuracy: 0.7736 - val_loss: 0.6289 - val_accuracy: 0.7800 - 16s/epoch - 41ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.62887
# 390/390 - 16s - loss: 0.6322 - accuracy: 0.7754 - val_loss: 0.6959 - val_accuracy: 0.7600 - 16s/epoch - 41ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.62887
# 390/390 - 16s - loss: 0.6268 - accuracy: 0.7748 - val_loss: 0.6869 - val_accuracy: 0.7642 - 16s/epoch - 42ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.62887
# 390/390 - 17s - loss: 0.6270 - accuracy: 0.7765 - val_loss: 0.6524 - val_accuracy: 0.7723 - 17s/epoch - 44ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.62887
# 390/390 - 16s - loss: 0.6229 - accuracy: 0.7781 - val_loss: 0.6679 - val_accuracy: 0.7745 - 16s/epoch - 41ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.62887
# 390/390 - 16s - loss: 0.6159 - accuracy: 0.7802 - val_loss: 0.6599 - val_accuracy: 0.7688 - 16s/epoch - 42ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.62887
# 390/390 - 16s - loss: 0.6202 - accuracy: 0.7793 - val_loss: 0.6616 - val_accuracy: 0.7727 - 16s/epoch - 42ms/step
# Epoch 75/100
#
# Epoch 75: val_loss did not improve from 0.62887
# 390/390 - 16s - loss: 0.6213 - accuracy: 0.7780 - val_loss: 0.6751 - val_accuracy: 0.7627 - 16s/epoch - 41ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.62887
# 390/390 - 17s - loss: 0.6054 - accuracy: 0.7888 - val_loss: 0.6409 - val_accuracy: 0.7798 - 17s/epoch - 42ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.62887
# 390/390 - 16s - loss: 0.6002 - accuracy: 0.7894 - val_loss: 0.6716 - val_accuracy: 0.7730 - 16s/epoch - 42ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.62887
# 390/390 - 17s - loss: 0.6038 - accuracy: 0.7874 - val_loss: 0.6352 - val_accuracy: 0.7845 - 17s/epoch - 44ms/step
# Epoch 79/100
#
# Epoch 79: val_loss improved from 0.62887 to 0.61867, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.6035 - accuracy: 0.7869 - val_loss: 0.6187 - val_accuracy: 0.7903 - 17s/epoch - 43ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.61867
# 390/390 - 16s - loss: 0.5973 - accuracy: 0.7876 - val_loss: 0.6524 - val_accuracy: 0.7772 - 16s/epoch - 40ms/step
# Epoch 81/100
#
# Epoch 81: val_loss improved from 0.61867 to 0.61259, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.5937 - accuracy: 0.7894 - val_loss: 0.6126 - val_accuracy: 0.7898 - 16s/epoch - 42ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.61259
# 390/390 - 16s - loss: 0.5956 - accuracy: 0.7891 - val_loss: 0.6628 - val_accuracy: 0.7760 - 16s/epoch - 41ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.61259
# 390/390 - 18s - loss: 0.5954 - accuracy: 0.7875 - val_loss: 0.6580 - val_accuracy: 0.7732 - 18s/epoch - 45ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.61259
# 390/390 - 17s - loss: 0.5888 - accuracy: 0.7900 - val_loss: 0.6308 - val_accuracy: 0.7878 - 17s/epoch - 43ms/step
# Epoch 85/100
#
# Epoch 85: val_loss improved from 0.61259 to 0.59625, saving model to model.100epochs.hdf5
# 390/390 - 19s - loss: 0.5903 - accuracy: 0.7911 - val_loss: 0.5963 - val_accuracy: 0.7970 - 19s/epoch - 49ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.59625
# 390/390 - 16s - loss: 0.5870 - accuracy: 0.7924 - val_loss: 0.6360 - val_accuracy: 0.7820 - 16s/epoch - 42ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.59625
# 390/390 - 17s - loss: 0.5829 - accuracy: 0.7928 - val_loss: 0.5993 - val_accuracy: 0.7932 - 17s/epoch - 43ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.59625
# 390/390 - 17s - loss: 0.5860 - accuracy: 0.7921 - val_loss: 0.6263 - val_accuracy: 0.7853 - 17s/epoch - 44ms/step
# Epoch 89/100
#
# Epoch 89: val_loss improved from 0.59625 to 0.58893, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.5780 - accuracy: 0.7970 - val_loss: 0.5889 - val_accuracy: 0.7983 - 17s/epoch - 43ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.58893
# 390/390 - 16s - loss: 0.5797 - accuracy: 0.7971 - val_loss: 0.6397 - val_accuracy: 0.7807 - 16s/epoch - 41ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.58893
# 390/390 - 17s - loss: 0.5766 - accuracy: 0.7964 - val_loss: 0.6028 - val_accuracy: 0.7948 - 17s/epoch - 44ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.58893
# 390/390 - 17s - loss: 0.5756 - accuracy: 0.7974 - val_loss: 0.6273 - val_accuracy: 0.7870 - 17s/epoch - 43ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.58893
# 390/390 - 17s - loss: 0.5673 - accuracy: 0.8024 - val_loss: 0.5898 - val_accuracy: 0.7975 - 17s/epoch - 44ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.58893
# 390/390 - 17s - loss: 0.5674 - accuracy: 0.8022 - val_loss: 0.5900 - val_accuracy: 0.7953 - 17s/epoch - 44ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.58893
# 390/390 - 16s - loss: 0.5640 - accuracy: 0.8033 - val_loss: 0.5989 - val_accuracy: 0.7938 - 16s/epoch - 42ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.58893
# 390/390 - 16s - loss: 0.5664 - accuracy: 0.7994 - val_loss: 0.6305 - val_accuracy: 0.7852 - 16s/epoch - 41ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.58893
# 390/390 - 16s - loss: 0.5594 - accuracy: 0.8048 - val_loss: 0.5925 - val_accuracy: 0.7980 - 16s/epoch - 42ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.58893
# 390/390 - 17s - loss: 0.5586 - accuracy: 0.8064 - val_loss: 0.6178 - val_accuracy: 0.7890 - 17s/epoch - 43ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.58893
# 390/390 - 16s - loss: 0.5568 - accuracy: 0.8069 - val_loss: 0.6447 - val_accuracy: 0.7802 - 16s/epoch - 42ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.58893
# 390/390 - 16s - loss: 0.5578 - accuracy: 0.8023 - val_loss: 0.5990 - val_accuracy: 0.7923 - 16s/epoch - 42ms/step

# %%
model.load_weights('model.100epochs.hdf5')
scores = model.evaluate(x_test_clas, y_test_clas, batch_size=128, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
# Out:
# 47/47 [==============================] - 1s 10ms/step - loss: 0.5889 - accuracy: 0.7983
#
# Test result: 79.833 loss: 0.589

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import seaborn as sns

# Make predictions
predictions = model.predict(x_test_clas)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test_clas, axis=1)

# Create confusion matrix
conf_matrix_clas = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix using seaborn
pyplot.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_clas, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(6), yticklabels=np.arange(6))
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.title('Confusion Matrix')
pyplot.show()

# Print classification report
class_report = classification_report(true_labels, predicted_labels)
print("\nClassification Report:")
print(class_report)
# Out:
# 188/188 [==============================] - 1s 4ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.89      0.87      0.88      1000
#            1       0.90      0.98      0.94      1000
#            2       0.77      0.72      0.74      1000
#            3       0.69      0.67      0.68      1000
#            4       0.74      0.85      0.80      1000
#            5       0.79      0.70      0.74      1000
#
#     accuracy                           0.80      6000
#    macro avg       0.80      0.80      0.80      6000
# weighted avg       0.80      0.80      0.80      6000

# %% [markdown]
# Clustering

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import Birch

# %%
X = x_test_clus.reshape(x_test_clus.shape[0], -1)
y = y_test_clus.reshape(-1)

# %%
# Apply t-SNE
tsne = TSNE(n_components=2, perplexity=30)
X_tsne = tsne.fit_transform(X)

# %%
Bir = Birch(n_clusters=4)
Bir.fit(X_tsne)
y_predX_tsne = Bir.fit_predict(X_tsne)

# %%
pyplot.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y_predX_tsne)
pyplot.xlabel('t-SNE component 1')
pyplot.ylabel('t-SNE component 2')
pyplot.title('CIFAR-10 dataset in the t-SNE 2D space with K-means clusters')
pyplot.show()

# %%
from sklearn.metrics import silhouette_samples
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(X, y_predX_tsne)
# Calculate silhouette scores for each data point
silhouette_values = silhouette_samples(X, y_predX_tsne)

# %%
# Create a bar plot
pyplot.figure(figsize=(8, 6))
y_lower = 10

for i in range(Bir.n_clusters):
    cluster_silhouette_values = silhouette_values[y_predX_tsne == i]
    cluster_silhouette_values.sort()

    size_cluster_i = cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = pyplot.cm.viridis(float(i) / Bir.n_clusters)
    pyplot.fill_betweenx(np.arange(y_lower, y_upper),
                      0, cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)

    # Label the silhouette plots with their cluster numbers at the middle
    pyplot.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for the next plot
    y_lower = y_upper + 10  # 10 for the 0 samples

pyplot.title("Silhouette plot for the various clusters")
pyplot.xlabel("Silhouette coefficient values")
pyplot.ylabel("Cluster label")

# The vertical line for average silhouette score of all the values
pyplot.axvline(x=silhouette_avg, color="red", linestyle="--")

pyplot.show()

# %%
y_test_cm = y_test_clus.reshape(-1)
mapping = {0: 6, 1: 7, 2: 8, 3: 9}
mapped_array = np.vectorize(mapping.get)(y_predX_tsne)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import seaborn as sns
predicted_labels_clus = mapped_array
true_labels = y_test_cm

# Create confusion matrix
conf_matrix_clus = confusion_matrix(true_labels, predicted_labels_clus)

# Plot the confusion matrix using seaborn
pyplot.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_clus, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(4), yticklabels=np.arange(4))
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.title('Confusion Matrix')
pyplot.show()

# Print classification report
class_report = classification_report(true_labels, predicted_labels_clus)
print("\nClassification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            6       0.47      0.63      0.54      1000
#            7       0.26      0.32      0.28      1000
#            8       0.27      0.26      0.27      1000
#            9       0.41      0.19      0.26      1000
#
#     accuracy                           0.35      4000
#    macro avg       0.35      0.35      0.34      4000
# weighted avg       0.35      0.35      0.34      4000

# %%
# Create a new matrix of zeros with dimensions 32x32
new_zeros = np.zeros((10, 10), dtype=int)
new_zeros[:6, :6] = conf_matrix_clas
new_zeros[6:10, 6:10] = conf_matrix_clus

# %%
# Create a figure with a specified size
pyplot.figure(figsize=(10, 8))

# Plot the combined confusion matrix
pyplot.figure(figsize=(10, 8))
sns.heatmap(new_zeros, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(10), yticklabels=np.arange(10))
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.title('Confusion Matrix')
pyplot.show()
