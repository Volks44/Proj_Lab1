# %% [markdown]
# <a href="https://colab.research.google.com/github/Volks44/Proj_Lab1/blob/main/1_Own_CCN_%26_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.datasets import cifar10
# !pip install np_utils --quiet
import np_utils as np_utils
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers, optimizers
import numpy as np
from matplotlib import pyplot
from keras.models import Sequential
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for np_utils (setup.py) ... done

# %%
# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 3s 0us/step

# %%
# Classes division
classes_for_clas = [0, 1, 2, 3, 4, 5]
classes_for_clus = [6,7,8,9]

# Filtering the data for classification
train_mask = np.isin(train_labels, classes_for_clas).flatten()
test_mask = np.isin(test_labels, classes_for_clas).flatten()

x_train_clas = train_images[train_mask]
y_train_clas = train_labels[train_mask]

x_test_clas = test_images[test_mask]
y_test_clas = test_labels[test_mask]

# Filtering the data for clustering
train_mask = np.isin(train_labels, classes_for_clus).flatten()
test_mask = np.isin(test_labels, classes_for_clus).flatten()

x_train_clus = train_images[train_mask]
y_train_clus = train_labels[train_mask]

x_test_clus = test_images[test_mask]
y_test_clus = test_labels[test_mask]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train_clas[i]))

# %%
# rescale [0,255] --> [0,1]
x_train_clas = x_train_clas.astype('float32')/255
x_test_clas = x_test_clas.astype('float32')/255

# %%
x_train_clas.shape
# Out:
# (30000, 32, 32, 3)

# %%
# one-hot encode the labels
num_classes = len(np.unique(y_train_clas))
y_train_clas = keras.utils.to_categorical(y_train_clas, num_classes)
y_test_clas = keras.utils.to_categorical(y_test_clas, num_classes)

# break training set into training and validation sets
(x_train_clas, x_valid_clas) = x_train_clas[5000:], x_train_clas[:5000]
(y_train_clas, y_valid_clas) = y_train_clas[5000:], y_train_clas[:5000]

# print shape of training set
print('x_train shape:', x_train_clas.shape)

# print number of training, validation, and test images
print(x_train_clas.shape[0], 'train samples')
print(x_test_clas.shape[0], 'test samples')
print(x_valid_clas.shape[0], 'validation samples')
# Out:
# x_train shape: (25000, 32, 32, 3)
# 25000 train samples
# 6000 test samples
# 5000 validation samples

# %%
# number of hidden units variable
base_hidden_units = 32

# l2 regularization hyperparameter
weight_decay = 1e-4

model = Sequential()

# CONV1
# notice that we defined the input_shape here because this is the first CONV layer.
# we don’t need to do that for the remaining layers
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train_clas.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV2
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# CONV3
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV4
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

# CONV5
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV6
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

# FC7
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

# print model summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  batch_normalization (Batch  (None, 32, 32, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_2 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_3 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_4 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_5 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 6)                 12294
#
# =================================================================
# Total params: 301094 (1.15 MB)
# Trainable params: 300198 (1.15 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
    )

# compute the data augmentation on the training set
datagen.fit(x_train_clas)

# %%
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

# training
batch_size = 64
epochs=100

checkpointer = ModelCheckpoint(filepath='model.100epochs.hdf5', verbose=1, save_best_only=True)

optimizer = Adam(learning_rate=0.0001)

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
history = model.fit(datagen.flow(x_train_clas, y_train_clas, batch_size=batch_size), callbacks=[checkpointer],
                steps_per_epoch=x_train_clas.shape[0] // batch_size, epochs=epochs,verbose=2,
                validation_data=(x_test_clas,y_test_clas))
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.20084, saving model to model.100epochs.hdf5
# 390/390 - 41s - loss: 2.3927 - accuracy: 0.3470 - val_loss: 2.2008 - val_accuracy: 0.2760 - 41s/epoch - 105ms/step
# Epoch 2/100
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2: val_loss improved from 2.20084 to 1.27112, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.7926 - accuracy: 0.4295 - val_loss: 1.2711 - val_accuracy: 0.5230 - 16s/epoch - 40ms/step
# Epoch 3/100
#
# Epoch 3: val_loss did not improve from 1.27112
# 390/390 - 17s - loss: 1.5762 - accuracy: 0.4565 - val_loss: 1.5081 - val_accuracy: 0.4993 - 17s/epoch - 43ms/step
# Epoch 4/100
#
# Epoch 4: val_loss did not improve from 1.27112
# 390/390 - 16s - loss: 1.4360 - accuracy: 0.4821 - val_loss: 1.2985 - val_accuracy: 0.5353 - 16s/epoch - 40ms/step
# Epoch 5/100
#
# Epoch 5: val_loss did not improve from 1.27112
# 390/390 - 16s - loss: 1.3624 - accuracy: 0.5054 - val_loss: 1.4149 - val_accuracy: 0.4947 - 16s/epoch - 40ms/step
# Epoch 6/100
#
# Epoch 6: val_loss improved from 1.27112 to 1.15576, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 1.3161 - accuracy: 0.5219 - val_loss: 1.1558 - val_accuracy: 0.5557 - 17s/epoch - 44ms/step
# Epoch 7/100
#
# Epoch 7: val_loss did not improve from 1.15576
# 390/390 - 17s - loss: 1.2625 - accuracy: 0.5389 - val_loss: 1.2836 - val_accuracy: 0.5240 - 17s/epoch - 43ms/step
# Epoch 8/100
#
# Epoch 8: val_loss did not improve from 1.15576
# 390/390 - 17s - loss: 1.2303 - accuracy: 0.5529 - val_loss: 1.2729 - val_accuracy: 0.5373 - 17s/epoch - 43ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 1.15576
# 390/390 - 16s - loss: 1.2009 - accuracy: 0.5687 - val_loss: 1.2754 - val_accuracy: 0.5280 - 16s/epoch - 40ms/step
# Epoch 10/100
#
# Epoch 10: val_loss did not improve from 1.15576
# 390/390 - 17s - loss: 1.1533 - accuracy: 0.5838 - val_loss: 1.2014 - val_accuracy: 0.5510 - 17s/epoch - 44ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 1.15576
# 390/390 - 16s - loss: 1.1324 - accuracy: 0.5893 - val_loss: 1.2117 - val_accuracy: 0.5725 - 16s/epoch - 42ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 1.15576
# 390/390 - 16s - loss: 1.1166 - accuracy: 0.5944 - val_loss: 1.2619 - val_accuracy: 0.5472 - 16s/epoch - 41ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 1.15576 to 1.09825, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.0829 - accuracy: 0.6013 - val_loss: 1.0983 - val_accuracy: 0.5978 - 16s/epoch - 40ms/step
# Epoch 14/100
#
# Epoch 14: val_loss improved from 1.09825 to 1.02312, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.0616 - accuracy: 0.6144 - val_loss: 1.0231 - val_accuracy: 0.6345 - 16s/epoch - 42ms/step
# Epoch 15/100
#
# Epoch 15: val_loss did not improve from 1.02312
# 390/390 - 16s - loss: 1.0410 - accuracy: 0.6200 - val_loss: 1.1389 - val_accuracy: 0.6095 - 16s/epoch - 41ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 1.02312 to 1.01507, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.0067 - accuracy: 0.6300 - val_loss: 1.0151 - val_accuracy: 0.6323 - 16s/epoch - 41ms/step
# Epoch 17/100
#
# Epoch 17: val_loss improved from 1.01507 to 0.97374, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 1.0046 - accuracy: 0.6332 - val_loss: 0.9737 - val_accuracy: 0.6450 - 17s/epoch - 44ms/step
# Epoch 18/100
#
# Epoch 18: val_loss did not improve from 0.97374
# 390/390 - 16s - loss: 0.9695 - accuracy: 0.6438 - val_loss: 1.0723 - val_accuracy: 0.6260 - 16s/epoch - 41ms/step
# Epoch 19/100
#
# Epoch 19: val_loss did not improve from 0.97374
# 390/390 - 16s - loss: 0.9708 - accuracy: 0.6467 - val_loss: 1.0219 - val_accuracy: 0.6535 - 16s/epoch - 41ms/step
# Epoch 20/100
#
# Epoch 20: val_loss did not improve from 0.97374
# 390/390 - 16s - loss: 0.9478 - accuracy: 0.6533 - val_loss: 0.9807 - val_accuracy: 0.6585 - 16s/epoch - 42ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.97374
# 390/390 - 16s - loss: 0.9332 - accuracy: 0.6610 - val_loss: 0.9815 - val_accuracy: 0.6538 - 16s/epoch - 42ms/step
# Epoch 22/100
#
# Epoch 22: val_loss improved from 0.97374 to 0.95657, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.9031 - accuracy: 0.6698 - val_loss: 0.9566 - val_accuracy: 0.6750 - 17s/epoch - 43ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.95657 to 0.93461, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.8996 - accuracy: 0.6692 - val_loss: 0.9346 - val_accuracy: 0.6843 - 16s/epoch - 42ms/step
# Epoch 24/100
#
# Epoch 24: val_loss improved from 0.93461 to 0.87219, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.8870 - accuracy: 0.6723 - val_loss: 0.8722 - val_accuracy: 0.6952 - 17s/epoch - 43ms/step
# Epoch 25/100
#
# Epoch 25: val_loss did not improve from 0.87219
# 390/390 - 16s - loss: 0.8761 - accuracy: 0.6781 - val_loss: 0.8841 - val_accuracy: 0.6902 - 16s/epoch - 42ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.87219
# 390/390 - 16s - loss: 0.8606 - accuracy: 0.6850 - val_loss: 1.0472 - val_accuracy: 0.6475 - 16s/epoch - 41ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.87219
# 390/390 - 16s - loss: 0.8530 - accuracy: 0.6872 - val_loss: 0.9017 - val_accuracy: 0.6815 - 16s/epoch - 42ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.87219
# 390/390 - 16s - loss: 0.8356 - accuracy: 0.6929 - val_loss: 0.9315 - val_accuracy: 0.6882 - 16s/epoch - 42ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.87219 to 0.86197, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.8309 - accuracy: 0.6963 - val_loss: 0.8620 - val_accuracy: 0.6910 - 17s/epoch - 44ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.86197 to 0.84440, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.8191 - accuracy: 0.7018 - val_loss: 0.8444 - val_accuracy: 0.7085 - 16s/epoch - 41ms/step
# Epoch 31/100
#
# Epoch 31: val_loss improved from 0.84440 to 0.83475, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.8168 - accuracy: 0.7020 - val_loss: 0.8348 - val_accuracy: 0.7088 - 16s/epoch - 42ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.83475
# 390/390 - 16s - loss: 0.8050 - accuracy: 0.7071 - val_loss: 0.8712 - val_accuracy: 0.6963 - 16s/epoch - 42ms/step
# Epoch 33/100
#
# Epoch 33: val_loss improved from 0.83475 to 0.77243, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.7929 - accuracy: 0.7093 - val_loss: 0.7724 - val_accuracy: 0.7292 - 16s/epoch - 41ms/step
# Epoch 34/100
#
# Epoch 34: val_loss did not improve from 0.77243
# 390/390 - 17s - loss: 0.7815 - accuracy: 0.7187 - val_loss: 0.8515 - val_accuracy: 0.7048 - 17s/epoch - 44ms/step
# Epoch 35/100
#
# Epoch 35: val_loss improved from 0.77243 to 0.75439, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.7746 - accuracy: 0.7180 - val_loss: 0.7544 - val_accuracy: 0.7332 - 16s/epoch - 42ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.75439
# 390/390 - 16s - loss: 0.7707 - accuracy: 0.7178 - val_loss: 0.8079 - val_accuracy: 0.7278 - 16s/epoch - 41ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.75439
# 390/390 - 16s - loss: 0.7567 - accuracy: 0.7269 - val_loss: 0.8764 - val_accuracy: 0.7110 - 16s/epoch - 42ms/step
# Epoch 38/100
#
# Epoch 38: val_loss improved from 0.75439 to 0.73798, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.7492 - accuracy: 0.7283 - val_loss: 0.7380 - val_accuracy: 0.7453 - 17s/epoch - 45ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.73798
# 390/390 - 17s - loss: 0.7442 - accuracy: 0.7301 - val_loss: 0.8385 - val_accuracy: 0.7132 - 17s/epoch - 43ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.73798
# 390/390 - 17s - loss: 0.7368 - accuracy: 0.7328 - val_loss: 0.8658 - val_accuracy: 0.7120 - 17s/epoch - 44ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.73798
# 390/390 - 16s - loss: 0.7383 - accuracy: 0.7328 - val_loss: 0.7495 - val_accuracy: 0.7443 - 16s/epoch - 41ms/step
# Epoch 42/100
#
# Epoch 42: val_loss did not improve from 0.73798
# 390/390 - 17s - loss: 0.7329 - accuracy: 0.7335 - val_loss: 0.8117 - val_accuracy: 0.7278 - 17s/epoch - 44ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.73798
# 390/390 - 16s - loss: 0.7280 - accuracy: 0.7357 - val_loss: 0.7544 - val_accuracy: 0.7387 - 16s/epoch - 42ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.73798
# 390/390 - 16s - loss: 0.7151 - accuracy: 0.7389 - val_loss: 0.8279 - val_accuracy: 0.7123 - 16s/epoch - 40ms/step
# Epoch 45/100
#
# Epoch 45: val_loss did not improve from 0.73798
# 390/390 - 16s - loss: 0.7190 - accuracy: 0.7404 - val_loss: 0.7591 - val_accuracy: 0.7425 - 16s/epoch - 42ms/step
# Epoch 46/100
#
# Epoch 46: val_loss improved from 0.73798 to 0.64764, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.7141 - accuracy: 0.7449 - val_loss: 0.6476 - val_accuracy: 0.7683 - 16s/epoch - 42ms/step
# Epoch 47/100
#
# Epoch 47: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.7087 - accuracy: 0.7434 - val_loss: 0.7424 - val_accuracy: 0.7433 - 16s/epoch - 42ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6946 - accuracy: 0.7494 - val_loss: 0.7956 - val_accuracy: 0.7338 - 16s/epoch - 42ms/step
# Epoch 49/100
#
# Epoch 49: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6944 - accuracy: 0.7498 - val_loss: 0.7584 - val_accuracy: 0.7468 - 16s/epoch - 42ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6931 - accuracy: 0.7488 - val_loss: 0.6903 - val_accuracy: 0.7647 - 16s/epoch - 42ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.64764
# 390/390 - 17s - loss: 0.6801 - accuracy: 0.7563 - val_loss: 0.6799 - val_accuracy: 0.7647 - 17s/epoch - 43ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6832 - accuracy: 0.7556 - val_loss: 0.6531 - val_accuracy: 0.7755 - 16s/epoch - 40ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6796 - accuracy: 0.7571 - val_loss: 0.7298 - val_accuracy: 0.7530 - 16s/epoch - 42ms/step
# Epoch 54/100
#
# Epoch 54: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6651 - accuracy: 0.7610 - val_loss: 0.7907 - val_accuracy: 0.7328 - 16s/epoch - 42ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6698 - accuracy: 0.7584 - val_loss: 0.6675 - val_accuracy: 0.7685 - 16s/epoch - 42ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6646 - accuracy: 0.7605 - val_loss: 0.6650 - val_accuracy: 0.7728 - 16s/epoch - 40ms/step
# Epoch 57/100
#
# Epoch 57: val_loss did not improve from 0.64764
# 390/390 - 15s - loss: 0.6606 - accuracy: 0.7654 - val_loss: 0.7357 - val_accuracy: 0.7497 - 15s/epoch - 40ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6610 - accuracy: 0.7622 - val_loss: 0.6885 - val_accuracy: 0.7647 - 16s/epoch - 42ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6503 - accuracy: 0.7655 - val_loss: 0.6900 - val_accuracy: 0.7610 - 16s/epoch - 40ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6477 - accuracy: 0.7701 - val_loss: 0.7677 - val_accuracy: 0.7415 - 16s/epoch - 42ms/step
# Epoch 61/100
#
# Epoch 61: val_loss did not improve from 0.64764
# 390/390 - 17s - loss: 0.6464 - accuracy: 0.7690 - val_loss: 0.6589 - val_accuracy: 0.7683 - 17s/epoch - 42ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6402 - accuracy: 0.7701 - val_loss: 0.6751 - val_accuracy: 0.7670 - 16s/epoch - 42ms/step
# Epoch 63/100
#
# Epoch 63: val_loss did not improve from 0.64764
# 390/390 - 17s - loss: 0.6364 - accuracy: 0.7740 - val_loss: 0.6635 - val_accuracy: 0.7693 - 17s/epoch - 42ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.64764
# 390/390 - 17s - loss: 0.6352 - accuracy: 0.7729 - val_loss: 0.6509 - val_accuracy: 0.7748 - 17s/epoch - 43ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.64764
# 390/390 - 16s - loss: 0.6284 - accuracy: 0.7774 - val_loss: 0.6695 - val_accuracy: 0.7798 - 16s/epoch - 42ms/step
# Epoch 66/100
#
# Epoch 66: val_loss improved from 0.64764 to 0.63016, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6251 - accuracy: 0.7777 - val_loss: 0.6302 - val_accuracy: 0.7850 - 16s/epoch - 40ms/step
# Epoch 67/100
#
# Epoch 67: val_loss improved from 0.63016 to 0.62564, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6244 - accuracy: 0.7745 - val_loss: 0.6256 - val_accuracy: 0.7847 - 16s/epoch - 42ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.62564
# 390/390 - 16s - loss: 0.6248 - accuracy: 0.7780 - val_loss: 0.6309 - val_accuracy: 0.7795 - 16s/epoch - 42ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.62564
# 390/390 - 18s - loss: 0.6208 - accuracy: 0.7798 - val_loss: 0.7085 - val_accuracy: 0.7690 - 18s/epoch - 45ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.62564
# 390/390 - 16s - loss: 0.6144 - accuracy: 0.7844 - val_loss: 0.6633 - val_accuracy: 0.7720 - 16s/epoch - 42ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.62564
# 390/390 - 16s - loss: 0.6087 - accuracy: 0.7846 - val_loss: 0.6479 - val_accuracy: 0.7732 - 16s/epoch - 42ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.62564
# 390/390 - 16s - loss: 0.6127 - accuracy: 0.7829 - val_loss: 0.6409 - val_accuracy: 0.7817 - 16s/epoch - 40ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.62564
# 390/390 - 16s - loss: 0.6050 - accuracy: 0.7863 - val_loss: 0.6697 - val_accuracy: 0.7697 - 16s/epoch - 42ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.62564
# 390/390 - 16s - loss: 0.6085 - accuracy: 0.7844 - val_loss: 0.6337 - val_accuracy: 0.7843 - 16s/epoch - 42ms/step
# Epoch 75/100
#
# Epoch 75: val_loss improved from 0.62564 to 0.61252, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6023 - accuracy: 0.7893 - val_loss: 0.6125 - val_accuracy: 0.7915 - 16s/epoch - 41ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.61252
# 390/390 - 16s - loss: 0.6002 - accuracy: 0.7875 - val_loss: 0.6307 - val_accuracy: 0.7910 - 16s/epoch - 42ms/step
# Epoch 77/100
#
# Epoch 77: val_loss improved from 0.61252 to 0.59165, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.5972 - accuracy: 0.7889 - val_loss: 0.5916 - val_accuracy: 0.7973 - 16s/epoch - 40ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.59165
# 390/390 - 17s - loss: 0.5897 - accuracy: 0.7926 - val_loss: 0.6115 - val_accuracy: 0.7937 - 17s/epoch - 43ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.59165
# 390/390 - 16s - loss: 0.5904 - accuracy: 0.7934 - val_loss: 0.6234 - val_accuracy: 0.7817 - 16s/epoch - 42ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.59165
# 390/390 - 16s - loss: 0.5832 - accuracy: 0.7934 - val_loss: 0.6397 - val_accuracy: 0.7755 - 16s/epoch - 40ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.59165
# 390/390 - 16s - loss: 0.5880 - accuracy: 0.7950 - val_loss: 0.6841 - val_accuracy: 0.7777 - 16s/epoch - 42ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.59165
# 390/390 - 15s - loss: 0.5825 - accuracy: 0.7938 - val_loss: 0.6084 - val_accuracy: 0.7933 - 15s/epoch - 40ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.59165
# 390/390 - 17s - loss: 0.5753 - accuracy: 0.7966 - val_loss: 0.5953 - val_accuracy: 0.7952 - 17s/epoch - 43ms/step
# Epoch 84/100
#
# Epoch 84: val_loss improved from 0.59165 to 0.57916, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 0.5812 - accuracy: 0.7937 - val_loss: 0.5792 - val_accuracy: 0.7990 - 17s/epoch - 43ms/step
# Epoch 85/100
#
# Epoch 85: val_loss did not improve from 0.57916
# 390/390 - 16s - loss: 0.5763 - accuracy: 0.7945 - val_loss: 0.6091 - val_accuracy: 0.7900 - 16s/epoch - 40ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.57916
# 390/390 - 16s - loss: 0.5816 - accuracy: 0.7958 - val_loss: 0.5892 - val_accuracy: 0.8007 - 16s/epoch - 40ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.57916
# 390/390 - 16s - loss: 0.5713 - accuracy: 0.7970 - val_loss: 0.6295 - val_accuracy: 0.7852 - 16s/epoch - 40ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.57916
# 390/390 - 16s - loss: 0.5682 - accuracy: 0.8013 - val_loss: 0.5866 - val_accuracy: 0.7973 - 16s/epoch - 42ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.57916
# 390/390 - 17s - loss: 0.5628 - accuracy: 0.8016 - val_loss: 0.6107 - val_accuracy: 0.7915 - 17s/epoch - 44ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.57916
# 390/390 - 16s - loss: 0.5737 - accuracy: 0.7983 - val_loss: 0.6552 - val_accuracy: 0.7865 - 16s/epoch - 42ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.57916
# 390/390 - 16s - loss: 0.5714 - accuracy: 0.7975 - val_loss: 0.6269 - val_accuracy: 0.7910 - 16s/epoch - 42ms/step
# Epoch 92/100
#
# Epoch 92: val_loss improved from 0.57916 to 0.57558, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.5642 - accuracy: 0.7984 - val_loss: 0.5756 - val_accuracy: 0.8030 - 16s/epoch - 42ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.57558
# 390/390 - 16s - loss: 0.5582 - accuracy: 0.8037 - val_loss: 0.6290 - val_accuracy: 0.7927 - 16s/epoch - 41ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.57558
# 390/390 - 17s - loss: 0.5550 - accuracy: 0.8069 - val_loss: 0.7347 - val_accuracy: 0.7660 - 17s/epoch - 43ms/step
# Epoch 95/100
#
# Epoch 95: val_loss did not improve from 0.57558
# 390/390 - 16s - loss: 0.5536 - accuracy: 0.8039 - val_loss: 0.6039 - val_accuracy: 0.7942 - 16s/epoch - 42ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.57558
# 390/390 - 16s - loss: 0.5495 - accuracy: 0.8055 - val_loss: 0.6003 - val_accuracy: 0.8050 - 16s/epoch - 40ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.57558
# 390/390 - 16s - loss: 0.5483 - accuracy: 0.8066 - val_loss: 0.5786 - val_accuracy: 0.8027 - 16s/epoch - 42ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.57558
# 390/390 - 16s - loss: 0.5482 - accuracy: 0.8076 - val_loss: 0.6017 - val_accuracy: 0.7975 - 16s/epoch - 41ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.57558
# 390/390 - 16s - loss: 0.5490 - accuracy: 0.8056 - val_loss: 0.5916 - val_accuracy: 0.8007 - 16s/epoch - 42ms/step
# Epoch 100/100
#
# Epoch 100: val_loss improved from 0.57558 to 0.57098, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.5524 - accuracy: 0.8074 - val_loss: 0.5710 - val_accuracy: 0.8107 - 16s/epoch - 42ms/step

# %%
model.load_weights('model.100epochs.hdf5')
scores = model.evaluate(x_test_clas, y_test_clas, batch_size=128, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
# Out:
# 47/47 [==============================] - 1s 9ms/step - loss: 0.5710 - accuracy: 0.8107
#
# Test result: 81.067 loss: 0.571

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import seaborn as sns

# Make predictions
predictions = model.predict(x_test_clas)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test_clas, axis=1)

# Create confusion matrix
conf_matrix_clas = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix using seaborn
pyplot.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_clas, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(6), yticklabels=np.arange(6))
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.title('Confusion Matrix')
pyplot.show()

# Print classification report
class_report = classification_report(true_labels, predicted_labels)
print("\nClassification Report:")
print(class_report)
# Out:
# 188/188 [==============================] - 1s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.87      0.90      0.88      1000
#            1       0.88      0.99      0.93      1000
#            2       0.80      0.75      0.77      1000
#            3       0.73      0.68      0.70      1000
#            4       0.74      0.90      0.81      1000
#            5       0.85      0.66      0.74      1000
#
#     accuracy                           0.81      6000
#    macro avg       0.81      0.81      0.81      6000
# weighted avg       0.81      0.81      0.81      6000

# %% [markdown]
# Clustering

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
X = x_test_clus.reshape(x_test_clus.shape[0], -1)
y = y_test_clus.reshape(-1)

# %%
# Apply t-SNE
tsne = TSNE(n_components=2, perplexity=30)
X_tsne = tsne.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(X_tsne)
y_predX_tsne = kmeans.predict(X_tsne)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
pyplot.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y_predX_tsne)
pyplot.xlabel('t-SNE component 1')
pyplot.ylabel('t-SNE component 2')
pyplot.title('CIFAR-10 dataset in the t-SNE 2D space with K-means clusters')
pyplot.show()

# %%
from sklearn.metrics import silhouette_samples
from sklearn.metrics import silhouette_score

silhouette_avg = silhouette_score(X, y_predX_tsne)
# Calculate silhouette scores for each data point
silhouette_values = silhouette_samples(X, y_predX_tsne)

# %%
# Create a bar plot
pyplot.figure(figsize=(8, 6))
y_lower = 10

for i in range(kmeans.n_clusters):
    cluster_silhouette_values = silhouette_values[y_predX_tsne == i]
    cluster_silhouette_values.sort()

    size_cluster_i = cluster_silhouette_values.shape[0]
    y_upper = y_lower + size_cluster_i

    color = pyplot.cm.viridis(float(i) / kmeans.n_clusters)
    pyplot.fill_betweenx(np.arange(y_lower, y_upper),
                      0, cluster_silhouette_values,
                      facecolor=color, edgecolor=color, alpha=0.7)

    # Label the silhouette plots with their cluster numbers at the middle
    pyplot.text(-0.05, y_lower + 0.5 * size_cluster_i, str(i))

    # Compute the new y_lower for the next plot
    y_lower = y_upper + 10  # 10 for the 0 samples

pyplot.title("Silhouette plot for the various clusters")
pyplot.xlabel("Silhouette coefficient values")
pyplot.ylabel("Cluster label")

# The vertical line for average silhouette score of all the values
pyplot.axvline(x=silhouette_avg, color="red", linestyle="--")

pyplot.show()

# %%
y_test_cm = y_test_clus.reshape(-1)
mapping = {0: 6, 1: 7, 2: 8, 3: 9}
mapped_array = np.vectorize(mapping.get)(y_predX_tsne)

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import seaborn as sns
predicted_labels_clus = mapped_array
true_labels = y_test_cm

# Create confusion matrix
conf_matrix_clus = confusion_matrix(true_labels, predicted_labels_clus)

# Plot the confusion matrix using seaborn
pyplot.figure(figsize=(6, 4))
sns.heatmap(conf_matrix_clus, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(4), yticklabels=np.arange(4))
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.title('Confusion Matrix')
pyplot.show()

# Print classification report
class_report = classification_report(true_labels, predicted_labels_clus)
print("\nClassification Report:")
print(class_report)
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            6       0.08      0.07      0.07      1000
#            7       0.25      0.27      0.26      1000
#            8       0.38      0.43      0.41      1000
#            9       0.14      0.13      0.14      1000
#
#     accuracy                           0.22      4000
#    macro avg       0.21      0.22      0.22      4000
# weighted avg       0.21      0.22      0.22      4000

# %%
# Create a new matrix of zeros with dimensions 32x32
new_zeros = np.zeros((10, 10), dtype=int)
new_zeros[:6, :6] = conf_matrix_clas
new_zeros[6:10, 6:10] = conf_matrix_clus

# %%
# Create a figure with a specified size
pyplot.figure(figsize=(10, 8))

# Plot the combined confusion matrix
pyplot.figure(figsize=(10, 8))
sns.heatmap(new_zeros, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(10), yticklabels=np.arange(10))
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.title('Confusion Matrix')
pyplot.show()
