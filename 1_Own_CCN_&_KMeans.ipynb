# %% [markdown]
# <a href="https://colab.research.google.com/github/Volks44/Proj_Lab1/blob/main/1_Own_CCN_%26_KMeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import keras
from keras.datasets import cifar10
# !pip install np_utils --quiet
import np_utils as np_utils
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
from keras.layers import Dense, Activation, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, MaxPooling2D
from keras import regularizers, optimizers
import numpy as np
from matplotlib import pyplot
from keras.models import Sequential
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.0/62.0 kB 2.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for np_utils (setup.py) ... done

# %%
# Load CIFAR-10 dataset
(train_images, train_labels), (test_images, test_labels) = cifar10.load_data()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 [==============================] - 7s 0us/step

# %%
# Classes division
classes_for_clas = [0, 1, 2, 3, 4, 5]
classes_for_clus = [6,7,8,9]

# Filtering the data for classification
train_mask = np.isin(train_labels, classes_for_clas).flatten()
test_mask = np.isin(test_labels, classes_for_clas).flatten()

x_train_clas = train_images[train_mask]
y_train_clas = train_labels[train_mask]

x_test_clas = test_images[test_mask]
y_test_clas = test_labels[test_mask]

# Filtering the data for clustering
train_mask = np.isin(train_labels, classes_for_clus).flatten()
test_mask = np.isin(test_labels, classes_for_clus).flatten()

x_train_clus = train_images[train_mask]
y_train_clus = train_labels[train_mask]

x_test_clus = test_images[test_mask]
y_test_clus = test_labels[test_mask]

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train_clas[i]))

# %%
# rescale [0,255] --> [0,1]
x_train_clas = x_train_clas.astype('float32')/255
x_test_clas = x_test_clas.astype('float32')/255

# %%
x_train_clas.shape
# Out:
# (30000, 32, 32, 3)

# %%
# one-hot encode the labels
num_classes = len(np.unique(y_train_clas))
y_train_clas = keras.utils.to_categorical(y_train_clas, num_classes)
y_test_clas = keras.utils.to_categorical(y_test_clas, num_classes)

# break training set into training and validation sets
(x_train_clas, x_valid_clas) = x_train_clas[5000:], x_train_clas[:5000]
(y_train_clas, y_valid_clas) = y_train_clas[5000:], y_train_clas[:5000]

# print shape of training set
print('x_train shape:', x_train_clas.shape)

# print number of training, validation, and test images
print(x_train_clas.shape[0], 'train samples')
print(x_test_clas.shape[0], 'test samples')
print(x_valid_clas.shape[0], 'validation samples')
# Out:
# x_train shape: (25000, 32, 32, 3)
# 25000 train samples
# 6000 test samples
# 5000 validation samples

# %%
# number of hidden units variable
base_hidden_units = 32

# l2 regularization hyperparameter
weight_decay = 1e-4

model = Sequential()

# CONV1
# notice that we defined the input_shape here because this is the first CONV layer.
# we don’t need to do that for the remaining layers
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay), input_shape=x_train_clas.shape[1:]))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV2
model.add(Conv2D(base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.2))

# CONV3
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV4
model.add(Conv2D(2*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.3))

# CONV5
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())

# CONV6
model.add(Conv2D(4*base_hidden_units, (3,3), padding='same', kernel_regularizer=regularizers.l2(weight_decay)))
model.add(Activation('relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

# FC7
model.add(Flatten())
model.add(Dense(num_classes, activation='softmax'))

# print model summary

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 32)        896
#
#  activation (Activation)     (None, 32, 32, 32)        0
#
#  batch_normalization (Batch  (None, 32, 32, 32)        128
#  Normalization)
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 32)        9248
#
#  activation_1 (Activation)   (None, 32, 32, 32)        0
#
#  batch_normalization_1 (Bat  (None, 32, 32, 32)        128
#  chNormalization)
#
#  max_pooling2d (MaxPooling2  (None, 16, 16, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 16, 16, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 64)        18496
#
#  activation_2 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_2 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 64)        36928
#
#  activation_3 (Activation)   (None, 16, 16, 64)        0
#
#  batch_normalization_3 (Bat  (None, 16, 16, 64)        256
#  chNormalization)
#
#  max_pooling2d_1 (MaxPoolin  (None, 8, 8, 64)          0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 64)          0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 128)         73856
#
#  activation_4 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_4 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 128)         147584
#
#  activation_5 (Activation)   (None, 8, 8, 128)         0
#
#  batch_normalization_5 (Bat  (None, 8, 8, 128)         512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPoolin  (None, 4, 4, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 128)         0
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dense (Dense)               (None, 6)                 12294
#
# =================================================================
# Total params: 301094 (1.15 MB)
# Trainable params: 300198 (1.15 MB)
# Non-trainable params: 896 (3.50 KB)
# _________________________________________________________________

# %%
datagen = ImageDataGenerator(
    featurewise_center=False,
    samplewise_center=False,
    featurewise_std_normalization=False,
    samplewise_std_normalization=False,
    zca_whitening=False,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    vertical_flip=True
    )

# compute the data augmentation on the training set
datagen.fit(x_train_clas)

# %%
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam

# training
batch_size = 64
epochs=100

checkpointer = ModelCheckpoint(filepath='model.100epochs.hdf5', verbose=1, save_best_only=True)

optimizer = Adam(learning_rate=0.0001)

model.compile(loss='categorical_crossentropy', optimizer=optimizer, metrics=['accuracy'])
history = model.fit(datagen.flow(x_train_clas, y_train_clas, batch_size=batch_size), callbacks=[checkpointer],
                steps_per_epoch=x_train_clas.shape[0] // batch_size, epochs=epochs,verbose=2,
                validation_data=(x_test_clas,y_test_clas))
# Out:
# Epoch 1/100
#
# Epoch 1: val_loss improved from inf to 2.12121, saving model to model.100epochs.hdf5
# 390/390 - 42s - loss: 2.4324 - accuracy: 0.3404 - val_loss: 2.1212 - val_accuracy: 0.2515 - 42s/epoch - 107ms/step
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3079: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# Epoch 2/100
#
# Epoch 2: val_loss improved from 2.12121 to 1.22909, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.8656 - accuracy: 0.4255 - val_loss: 1.2291 - val_accuracy: 0.5443 - 16s/epoch - 41ms/step
# Epoch 3/100
#
# Epoch 3: val_loss improved from 1.22909 to 1.22686, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 1.6127 - accuracy: 0.4530 - val_loss: 1.2269 - val_accuracy: 0.5460 - 17s/epoch - 43ms/step
# Epoch 4/100
#
# Epoch 4: val_loss improved from 1.22686 to 1.17581, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 1.4779 - accuracy: 0.4763 - val_loss: 1.1758 - val_accuracy: 0.5588 - 15s/epoch - 39ms/step
# Epoch 5/100
#
# Epoch 5: val_loss improved from 1.17581 to 1.17272, saving model to model.100epochs.hdf5
# 390/390 - 17s - loss: 1.3871 - accuracy: 0.4970 - val_loss: 1.1727 - val_accuracy: 0.5522 - 17s/epoch - 42ms/step
# Epoch 6/100
#
# Epoch 6: val_loss did not improve from 1.17272
# 390/390 - 17s - loss: 1.3339 - accuracy: 0.5146 - val_loss: 1.1803 - val_accuracy: 0.5475 - 17s/epoch - 44ms/step
# Epoch 7/100
#
# Epoch 7: val_loss improved from 1.17272 to 1.16299, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 1.2838 - accuracy: 0.5319 - val_loss: 1.1630 - val_accuracy: 0.5505 - 15s/epoch - 39ms/step
# Epoch 8/100
#
# Epoch 8: val_loss improved from 1.16299 to 1.11320, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 1.2337 - accuracy: 0.5480 - val_loss: 1.1132 - val_accuracy: 0.5770 - 15s/epoch - 39ms/step
# Epoch 9/100
#
# Epoch 9: val_loss did not improve from 1.11320
# 390/390 - 17s - loss: 1.1961 - accuracy: 0.5610 - val_loss: 1.2050 - val_accuracy: 0.5360 - 17s/epoch - 43ms/step
# Epoch 10/100
#
# Epoch 10: val_loss improved from 1.11320 to 1.09687, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 1.1716 - accuracy: 0.5727 - val_loss: 1.0969 - val_accuracy: 0.5850 - 15s/epoch - 39ms/step
# Epoch 11/100
#
# Epoch 11: val_loss did not improve from 1.09687
# 390/390 - 15s - loss: 1.1387 - accuracy: 0.5842 - val_loss: 1.2328 - val_accuracy: 0.5365 - 15s/epoch - 39ms/step
# Epoch 12/100
#
# Epoch 12: val_loss did not improve from 1.09687
# 390/390 - 16s - loss: 1.1139 - accuracy: 0.5906 - val_loss: 1.2644 - val_accuracy: 0.5258 - 16s/epoch - 41ms/step
# Epoch 13/100
#
# Epoch 13: val_loss improved from 1.09687 to 1.09579, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 1.0888 - accuracy: 0.6004 - val_loss: 1.0958 - val_accuracy: 0.5870 - 15s/epoch - 40ms/step
# Epoch 14/100
#
# Epoch 14: val_loss did not improve from 1.09579
# 390/390 - 16s - loss: 1.0592 - accuracy: 0.6091 - val_loss: 1.1423 - val_accuracy: 0.5657 - 16s/epoch - 41ms/step
# Epoch 15/100
#
# Epoch 15: val_loss improved from 1.09579 to 1.01042, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 1.0423 - accuracy: 0.6153 - val_loss: 1.0104 - val_accuracy: 0.6232 - 16s/epoch - 41ms/step
# Epoch 16/100
#
# Epoch 16: val_loss improved from 1.01042 to 0.99305, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 1.0203 - accuracy: 0.6215 - val_loss: 0.9931 - val_accuracy: 0.6195 - 15s/epoch - 40ms/step
# Epoch 17/100
#
# Epoch 17: val_loss did not improve from 0.99305
# 390/390 - 15s - loss: 1.0130 - accuracy: 0.6288 - val_loss: 1.0408 - val_accuracy: 0.6177 - 15s/epoch - 39ms/step
# Epoch 18/100
#
# Epoch 18: val_loss improved from 0.99305 to 0.95162, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 0.9915 - accuracy: 0.6389 - val_loss: 0.9516 - val_accuracy: 0.6460 - 15s/epoch - 40ms/step
# Epoch 19/100
#
# Epoch 19: val_loss improved from 0.95162 to 0.91447, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 0.9688 - accuracy: 0.6452 - val_loss: 0.9145 - val_accuracy: 0.6532 - 15s/epoch - 40ms/step
# Epoch 20/100
#
# Epoch 20: val_loss improved from 0.91447 to 0.88191, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.9572 - accuracy: 0.6495 - val_loss: 0.8819 - val_accuracy: 0.6787 - 16s/epoch - 42ms/step
# Epoch 21/100
#
# Epoch 21: val_loss did not improve from 0.88191
# 390/390 - 16s - loss: 0.9361 - accuracy: 0.6579 - val_loss: 0.9028 - val_accuracy: 0.6618 - 16s/epoch - 41ms/step
# Epoch 22/100
#
# Epoch 22: val_loss did not improve from 0.88191
# 390/390 - 15s - loss: 0.9303 - accuracy: 0.6591 - val_loss: 0.9404 - val_accuracy: 0.6538 - 15s/epoch - 39ms/step
# Epoch 23/100
#
# Epoch 23: val_loss improved from 0.88191 to 0.84993, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 0.8991 - accuracy: 0.6673 - val_loss: 0.8499 - val_accuracy: 0.6910 - 15s/epoch - 39ms/step
# Epoch 24/100
#
# Epoch 24: val_loss did not improve from 0.84993
# 390/390 - 15s - loss: 0.9000 - accuracy: 0.6686 - val_loss: 0.8864 - val_accuracy: 0.6697 - 15s/epoch - 39ms/step
# Epoch 25/100
#
# Epoch 25: val_loss improved from 0.84993 to 0.83550, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.8785 - accuracy: 0.6792 - val_loss: 0.8355 - val_accuracy: 0.6880 - 16s/epoch - 41ms/step
# Epoch 26/100
#
# Epoch 26: val_loss did not improve from 0.83550
# 390/390 - 15s - loss: 0.8747 - accuracy: 0.6785 - val_loss: 0.8721 - val_accuracy: 0.6805 - 15s/epoch - 39ms/step
# Epoch 27/100
#
# Epoch 27: val_loss did not improve from 0.83550
# 390/390 - 15s - loss: 0.8561 - accuracy: 0.6852 - val_loss: 0.8541 - val_accuracy: 0.6928 - 15s/epoch - 39ms/step
# Epoch 28/100
#
# Epoch 28: val_loss did not improve from 0.83550
# 390/390 - 16s - loss: 0.8507 - accuracy: 0.6889 - val_loss: 0.8719 - val_accuracy: 0.6913 - 16s/epoch - 40ms/step
# Epoch 29/100
#
# Epoch 29: val_loss improved from 0.83550 to 0.79413, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.8434 - accuracy: 0.6926 - val_loss: 0.7941 - val_accuracy: 0.7142 - 16s/epoch - 42ms/step
# Epoch 30/100
#
# Epoch 30: val_loss improved from 0.79413 to 0.77934, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 0.8262 - accuracy: 0.6966 - val_loss: 0.7793 - val_accuracy: 0.7115 - 15s/epoch - 40ms/step
# Epoch 31/100
#
# Epoch 31: val_loss did not improve from 0.77934
# 390/390 - 15s - loss: 0.8198 - accuracy: 0.7003 - val_loss: 0.7885 - val_accuracy: 0.7130 - 15s/epoch - 39ms/step
# Epoch 32/100
#
# Epoch 32: val_loss did not improve from 0.77934
# 390/390 - 15s - loss: 0.8108 - accuracy: 0.7041 - val_loss: 0.8172 - val_accuracy: 0.7095 - 15s/epoch - 39ms/step
# Epoch 33/100
#
# Epoch 33: val_loss did not improve from 0.77934
# 390/390 - 16s - loss: 0.8052 - accuracy: 0.7064 - val_loss: 0.8396 - val_accuracy: 0.7065 - 16s/epoch - 40ms/step
# Epoch 34/100
#
# Epoch 34: val_loss improved from 0.77934 to 0.74295, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 0.7977 - accuracy: 0.7079 - val_loss: 0.7429 - val_accuracy: 0.7292 - 15s/epoch - 39ms/step
# Epoch 35/100
#
# Epoch 35: val_loss did not improve from 0.74295
# 390/390 - 16s - loss: 0.7879 - accuracy: 0.7137 - val_loss: 0.7499 - val_accuracy: 0.7413 - 16s/epoch - 41ms/step
# Epoch 36/100
#
# Epoch 36: val_loss did not improve from 0.74295
# 390/390 - 15s - loss: 0.7810 - accuracy: 0.7143 - val_loss: 0.7441 - val_accuracy: 0.7317 - 15s/epoch - 39ms/step
# Epoch 37/100
#
# Epoch 37: val_loss did not improve from 0.74295
# 390/390 - 15s - loss: 0.7732 - accuracy: 0.7190 - val_loss: 0.7492 - val_accuracy: 0.7338 - 15s/epoch - 39ms/step
# Epoch 38/100
#
# Epoch 38: val_loss did not improve from 0.74295
# 390/390 - 16s - loss: 0.7665 - accuracy: 0.7176 - val_loss: 0.7487 - val_accuracy: 0.7310 - 16s/epoch - 40ms/step
# Epoch 39/100
#
# Epoch 39: val_loss did not improve from 0.74295
# 390/390 - 16s - loss: 0.7620 - accuracy: 0.7238 - val_loss: 0.7953 - val_accuracy: 0.7143 - 16s/epoch - 42ms/step
# Epoch 40/100
#
# Epoch 40: val_loss did not improve from 0.74295
# 390/390 - 15s - loss: 0.7523 - accuracy: 0.7224 - val_loss: 0.8647 - val_accuracy: 0.6982 - 15s/epoch - 39ms/step
# Epoch 41/100
#
# Epoch 41: val_loss did not improve from 0.74295
# 390/390 - 15s - loss: 0.7490 - accuracy: 0.7264 - val_loss: 0.7869 - val_accuracy: 0.7175 - 15s/epoch - 39ms/step
# Epoch 42/100
#
# Epoch 42: val_loss improved from 0.74295 to 0.73650, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.7392 - accuracy: 0.7280 - val_loss: 0.7365 - val_accuracy: 0.7373 - 16s/epoch - 41ms/step
# Epoch 43/100
#
# Epoch 43: val_loss did not improve from 0.73650
# 390/390 - 15s - loss: 0.7377 - accuracy: 0.7306 - val_loss: 0.7964 - val_accuracy: 0.7137 - 15s/epoch - 39ms/step
# Epoch 44/100
#
# Epoch 44: val_loss did not improve from 0.73650
# 390/390 - 17s - loss: 0.7409 - accuracy: 0.7312 - val_loss: 0.7811 - val_accuracy: 0.7288 - 17s/epoch - 43ms/step
# Epoch 45/100
#
# Epoch 45: val_loss improved from 0.73650 to 0.73422, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 0.7251 - accuracy: 0.7362 - val_loss: 0.7342 - val_accuracy: 0.7432 - 15s/epoch - 40ms/step
# Epoch 46/100
#
# Epoch 46: val_loss did not improve from 0.73422
# 390/390 - 15s - loss: 0.7270 - accuracy: 0.7358 - val_loss: 0.7716 - val_accuracy: 0.7240 - 15s/epoch - 39ms/step
# Epoch 47/100
#
# Epoch 47: val_loss improved from 0.73422 to 0.73089, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.7219 - accuracy: 0.7366 - val_loss: 0.7309 - val_accuracy: 0.7433 - 16s/epoch - 41ms/step
# Epoch 48/100
#
# Epoch 48: val_loss did not improve from 0.73089
# 390/390 - 15s - loss: 0.7142 - accuracy: 0.7408 - val_loss: 0.7364 - val_accuracy: 0.7423 - 15s/epoch - 39ms/step
# Epoch 49/100
#
# Epoch 49: val_loss improved from 0.73089 to 0.70150, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.7073 - accuracy: 0.7442 - val_loss: 0.7015 - val_accuracy: 0.7563 - 16s/epoch - 41ms/step
# Epoch 50/100
#
# Epoch 50: val_loss did not improve from 0.70150
# 390/390 - 15s - loss: 0.7051 - accuracy: 0.7476 - val_loss: 0.7202 - val_accuracy: 0.7502 - 15s/epoch - 39ms/step
# Epoch 51/100
#
# Epoch 51: val_loss did not improve from 0.70150
# 390/390 - 16s - loss: 0.7010 - accuracy: 0.7486 - val_loss: 0.7069 - val_accuracy: 0.7522 - 16s/epoch - 40ms/step
# Epoch 52/100
#
# Epoch 52: val_loss did not improve from 0.70150
# 390/390 - 16s - loss: 0.6901 - accuracy: 0.7520 - val_loss: 0.7274 - val_accuracy: 0.7467 - 16s/epoch - 41ms/step
# Epoch 53/100
#
# Epoch 53: val_loss did not improve from 0.70150
# 390/390 - 16s - loss: 0.6909 - accuracy: 0.7522 - val_loss: 0.7068 - val_accuracy: 0.7540 - 16s/epoch - 41ms/step
# Epoch 54/100
#
# Epoch 54: val_loss improved from 0.70150 to 0.69318, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 0.6827 - accuracy: 0.7514 - val_loss: 0.6932 - val_accuracy: 0.7635 - 15s/epoch - 39ms/step
# Epoch 55/100
#
# Epoch 55: val_loss did not improve from 0.69318
# 390/390 - 16s - loss: 0.6837 - accuracy: 0.7525 - val_loss: 0.7220 - val_accuracy: 0.7508 - 16s/epoch - 40ms/step
# Epoch 56/100
#
# Epoch 56: val_loss did not improve from 0.69318
# 390/390 - 15s - loss: 0.6826 - accuracy: 0.7540 - val_loss: 0.7032 - val_accuracy: 0.7537 - 15s/epoch - 39ms/step
# Epoch 57/100
#
# Epoch 57: val_loss improved from 0.69318 to 0.67194, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6681 - accuracy: 0.7584 - val_loss: 0.6719 - val_accuracy: 0.7745 - 16s/epoch - 40ms/step
# Epoch 58/100
#
# Epoch 58: val_loss did not improve from 0.67194
# 390/390 - 16s - loss: 0.6638 - accuracy: 0.7603 - val_loss: 0.7073 - val_accuracy: 0.7488 - 16s/epoch - 41ms/step
# Epoch 59/100
#
# Epoch 59: val_loss did not improve from 0.67194
# 390/390 - 16s - loss: 0.6571 - accuracy: 0.7644 - val_loss: 0.6781 - val_accuracy: 0.7635 - 16s/epoch - 41ms/step
# Epoch 60/100
#
# Epoch 60: val_loss did not improve from 0.67194
# 390/390 - 16s - loss: 0.6565 - accuracy: 0.7626 - val_loss: 0.7092 - val_accuracy: 0.7523 - 16s/epoch - 41ms/step
# Epoch 61/100
#
# Epoch 61: val_loss improved from 0.67194 to 0.63833, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6592 - accuracy: 0.7624 - val_loss: 0.6383 - val_accuracy: 0.7852 - 16s/epoch - 41ms/step
# Epoch 62/100
#
# Epoch 62: val_loss did not improve from 0.63833
# 390/390 - 16s - loss: 0.6516 - accuracy: 0.7678 - val_loss: 0.6385 - val_accuracy: 0.7785 - 16s/epoch - 40ms/step
# Epoch 63/100
#
# Epoch 63: val_loss improved from 0.63833 to 0.63603, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.6526 - accuracy: 0.7637 - val_loss: 0.6360 - val_accuracy: 0.7802 - 16s/epoch - 42ms/step
# Epoch 64/100
#
# Epoch 64: val_loss did not improve from 0.63603
# 390/390 - 15s - loss: 0.6506 - accuracy: 0.7657 - val_loss: 0.6481 - val_accuracy: 0.7755 - 15s/epoch - 39ms/step
# Epoch 65/100
#
# Epoch 65: val_loss did not improve from 0.63603
# 390/390 - 15s - loss: 0.6425 - accuracy: 0.7666 - val_loss: 0.6810 - val_accuracy: 0.7660 - 15s/epoch - 39ms/step
# Epoch 66/100
#
# Epoch 66: val_loss improved from 0.63603 to 0.62700, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 0.6411 - accuracy: 0.7745 - val_loss: 0.6270 - val_accuracy: 0.7848 - 15s/epoch - 39ms/step
# Epoch 67/100
#
# Epoch 67: val_loss did not improve from 0.62700
# 390/390 - 16s - loss: 0.6407 - accuracy: 0.7718 - val_loss: 0.6672 - val_accuracy: 0.7758 - 16s/epoch - 41ms/step
# Epoch 68/100
#
# Epoch 68: val_loss did not improve from 0.62700
# 390/390 - 15s - loss: 0.6342 - accuracy: 0.7712 - val_loss: 0.6421 - val_accuracy: 0.7797 - 15s/epoch - 39ms/step
# Epoch 69/100
#
# Epoch 69: val_loss did not improve from 0.62700
# 390/390 - 16s - loss: 0.6279 - accuracy: 0.7755 - val_loss: 0.6436 - val_accuracy: 0.7778 - 16s/epoch - 41ms/step
# Epoch 70/100
#
# Epoch 70: val_loss did not improve from 0.62700
# 390/390 - 16s - loss: 0.6313 - accuracy: 0.7736 - val_loss: 0.6937 - val_accuracy: 0.7578 - 16s/epoch - 40ms/step
# Epoch 71/100
#
# Epoch 71: val_loss did not improve from 0.62700
# 390/390 - 16s - loss: 0.6293 - accuracy: 0.7733 - val_loss: 0.6436 - val_accuracy: 0.7720 - 16s/epoch - 41ms/step
# Epoch 72/100
#
# Epoch 72: val_loss did not improve from 0.62700
# 390/390 - 16s - loss: 0.6252 - accuracy: 0.7803 - val_loss: 0.6370 - val_accuracy: 0.7800 - 16s/epoch - 40ms/step
# Epoch 73/100
#
# Epoch 73: val_loss did not improve from 0.62700
# 390/390 - 15s - loss: 0.6260 - accuracy: 0.7751 - val_loss: 0.6640 - val_accuracy: 0.7718 - 15s/epoch - 39ms/step
# Epoch 74/100
#
# Epoch 74: val_loss did not improve from 0.62700
# 390/390 - 15s - loss: 0.6219 - accuracy: 0.7787 - val_loss: 0.6509 - val_accuracy: 0.7770 - 15s/epoch - 40ms/step
# Epoch 75/100
#
# Epoch 75: val_loss improved from 0.62700 to 0.61314, saving model to model.100epochs.hdf5
# 390/390 - 15s - loss: 0.6160 - accuracy: 0.7811 - val_loss: 0.6131 - val_accuracy: 0.7860 - 15s/epoch - 39ms/step
# Epoch 76/100
#
# Epoch 76: val_loss did not improve from 0.61314
# 390/390 - 16s - loss: 0.6136 - accuracy: 0.7803 - val_loss: 0.6366 - val_accuracy: 0.7837 - 16s/epoch - 42ms/step
# Epoch 77/100
#
# Epoch 77: val_loss did not improve from 0.61314
# 390/390 - 16s - loss: 0.6052 - accuracy: 0.7835 - val_loss: 0.6196 - val_accuracy: 0.7887 - 16s/epoch - 40ms/step
# Epoch 78/100
#
# Epoch 78: val_loss did not improve from 0.61314
# 390/390 - 15s - loss: 0.6068 - accuracy: 0.7859 - val_loss: 0.6581 - val_accuracy: 0.7723 - 15s/epoch - 39ms/step
# Epoch 79/100
#
# Epoch 79: val_loss did not improve from 0.61314
# 390/390 - 15s - loss: 0.6106 - accuracy: 0.7836 - val_loss: 0.6693 - val_accuracy: 0.7628 - 15s/epoch - 39ms/step
# Epoch 80/100
#
# Epoch 80: val_loss did not improve from 0.61314
# 390/390 - 15s - loss: 0.6058 - accuracy: 0.7844 - val_loss: 0.6311 - val_accuracy: 0.7898 - 15s/epoch - 40ms/step
# Epoch 81/100
#
# Epoch 81: val_loss did not improve from 0.61314
# 390/390 - 15s - loss: 0.6015 - accuracy: 0.7905 - val_loss: 0.6405 - val_accuracy: 0.7820 - 15s/epoch - 39ms/step
# Epoch 82/100
#
# Epoch 82: val_loss did not improve from 0.61314
# 390/390 - 16s - loss: 0.5825 - accuracy: 0.7951 - val_loss: 0.6504 - val_accuracy: 0.7823 - 16s/epoch - 41ms/step
# Epoch 83/100
#
# Epoch 83: val_loss did not improve from 0.61314
# 390/390 - 15s - loss: 0.5922 - accuracy: 0.7886 - val_loss: 0.6250 - val_accuracy: 0.7832 - 15s/epoch - 39ms/step
# Epoch 84/100
#
# Epoch 84: val_loss did not improve from 0.61314
# 390/390 - 15s - loss: 0.5961 - accuracy: 0.7887 - val_loss: 0.6324 - val_accuracy: 0.7883 - 15s/epoch - 39ms/step
# Epoch 85/100
#
# Epoch 85: val_loss improved from 0.61314 to 0.59669, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.5819 - accuracy: 0.7940 - val_loss: 0.5967 - val_accuracy: 0.7938 - 16s/epoch - 40ms/step
# Epoch 86/100
#
# Epoch 86: val_loss did not improve from 0.59669
# 390/390 - 17s - loss: 0.5856 - accuracy: 0.7941 - val_loss: 0.6030 - val_accuracy: 0.7907 - 17s/epoch - 43ms/step
# Epoch 87/100
#
# Epoch 87: val_loss did not improve from 0.59669
# 390/390 - 16s - loss: 0.5873 - accuracy: 0.7922 - val_loss: 0.6388 - val_accuracy: 0.7793 - 16s/epoch - 41ms/step
# Epoch 88/100
#
# Epoch 88: val_loss did not improve from 0.59669
# 390/390 - 16s - loss: 0.5869 - accuracy: 0.7899 - val_loss: 0.6030 - val_accuracy: 0.7947 - 16s/epoch - 41ms/step
# Epoch 89/100
#
# Epoch 89: val_loss did not improve from 0.59669
# 390/390 - 15s - loss: 0.5819 - accuracy: 0.7954 - val_loss: 0.7007 - val_accuracy: 0.7618 - 15s/epoch - 39ms/step
# Epoch 90/100
#
# Epoch 90: val_loss did not improve from 0.59669
# 390/390 - 16s - loss: 0.5790 - accuracy: 0.7956 - val_loss: 0.6458 - val_accuracy: 0.7792 - 16s/epoch - 40ms/step
# Epoch 91/100
#
# Epoch 91: val_loss did not improve from 0.59669
# 390/390 - 16s - loss: 0.5787 - accuracy: 0.7946 - val_loss: 0.5998 - val_accuracy: 0.8032 - 16s/epoch - 41ms/step
# Epoch 92/100
#
# Epoch 92: val_loss did not improve from 0.59669
# 390/390 - 16s - loss: 0.5741 - accuracy: 0.7967 - val_loss: 0.6256 - val_accuracy: 0.7873 - 16s/epoch - 40ms/step
# Epoch 93/100
#
# Epoch 93: val_loss did not improve from 0.59669
# 390/390 - 16s - loss: 0.5719 - accuracy: 0.7976 - val_loss: 0.6110 - val_accuracy: 0.7978 - 16s/epoch - 40ms/step
# Epoch 94/100
#
# Epoch 94: val_loss did not improve from 0.59669
# 390/390 - 15s - loss: 0.5691 - accuracy: 0.7981 - val_loss: 0.6149 - val_accuracy: 0.7932 - 15s/epoch - 39ms/step
# Epoch 95/100
#
# Epoch 95: val_loss improved from 0.59669 to 0.57069, saving model to model.100epochs.hdf5
# 390/390 - 16s - loss: 0.5679 - accuracy: 0.8003 - val_loss: 0.5707 - val_accuracy: 0.8052 - 16s/epoch - 40ms/step
# Epoch 96/100
#
# Epoch 96: val_loss did not improve from 0.57069
# 390/390 - 15s - loss: 0.5627 - accuracy: 0.8007 - val_loss: 0.6068 - val_accuracy: 0.7963 - 15s/epoch - 39ms/step
# Epoch 97/100
#
# Epoch 97: val_loss did not improve from 0.57069
# 390/390 - 16s - loss: 0.5589 - accuracy: 0.8011 - val_loss: 0.6007 - val_accuracy: 0.7965 - 16s/epoch - 42ms/step
# Epoch 98/100
#
# Epoch 98: val_loss did not improve from 0.57069
# 390/390 - 15s - loss: 0.5626 - accuracy: 0.8045 - val_loss: 0.6080 - val_accuracy: 0.7938 - 15s/epoch - 39ms/step
# Epoch 99/100
#
# Epoch 99: val_loss did not improve from 0.57069
# 390/390 - 16s - loss: 0.5602 - accuracy: 0.8022 - val_loss: 0.5975 - val_accuracy: 0.7987 - 16s/epoch - 41ms/step
# Epoch 100/100
#
# Epoch 100: val_loss did not improve from 0.57069
# 390/390 - 15s - loss: 0.5518 - accuracy: 0.8070 - val_loss: 0.6029 - val_accuracy: 0.7925 - 15s/epoch - 39ms/step

# %%
model.load_weights('model.100epochs.hdf5')
scores = model.evaluate(x_test_clas, y_test_clas, batch_size=128, verbose=1)
print('\nTest result: %.3f loss: %.3f' % (scores[1]*100,scores[0]))
# Out:
# 47/47 [==============================] - 1s 11ms/step - loss: 0.5707 - accuracy: 0.8052
#
# Test result: 80.517 loss: 0.571

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, classification_report
import seaborn as sns

# Make predictions
predictions = model.predict(x_test_clas)
predicted_labels = np.argmax(predictions, axis=1)
true_labels = np.argmax(y_test_clas, axis=1)

# Create confusion matrix
conf_matrix = confusion_matrix(true_labels, predicted_labels)

# Plot the confusion matrix using seaborn
pyplot.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=np.arange(6), yticklabels=np.arange(6))
pyplot.xlabel('Predicted')
pyplot.ylabel('True')
pyplot.title('Confusion Matrix')
pyplot.show()

# Print classification report
class_report = classification_report(true_labels, predicted_labels)
print("\nClassification Report:")
print(class_report)
# Out:
# 188/188 [==============================] - 1s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.90      0.89      1000
#            1       0.94      0.97      0.95      1000
#            2       0.76      0.74      0.75      1000
#            3       0.72      0.65      0.68      1000
#            4       0.74      0.89      0.81      1000
#            5       0.80      0.68      0.74      1000
#
#     accuracy                           0.81      6000
#    macro avg       0.80      0.81      0.80      6000
# weighted avg       0.80      0.81      0.80      6000

# %% [markdown]
# Clustering

# %%
from sklearn.manifold import TSNE
from sklearn.cluster import KMeans

# %%
X = x_train_clus.reshape(x_train_clus.shape[0], -1)
y = y_train_clus.reshape(-1)

# %%
# Apply t-SNE
tsne = TSNE(n_components=2, perplexity=30)
X_tsne = tsne.fit_transform(X)

# %%
kmeans = KMeans(n_clusters=4, random_state=0)
kmeans.fit(X_tsne)
y_predX_tsne = kmeans.predict(X_tsne)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
pyplot.scatter(X_tsne[:, 0], X_tsne[:, 1], c=y_predX_tsne)
pyplot.xlabel('t-SNE component 1')
pyplot.ylabel('t-SNE component 2')
pyplot.title('CIFAR-10 dataset in the t-SNE 2D space with K-means clusters')
pyplot.show()
